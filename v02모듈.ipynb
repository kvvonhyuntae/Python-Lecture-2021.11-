# %% [markdown]
# # 모듈사용하기

# %% [markdown]
# ### 1. 모듈 사용하기

# %%
import math
print(f'floor(7.2) = {math.floor(7.2)}')
print(f'ceil(7.2) = {math.ceil(7.2)}')
# Out:
# floor(7.2) = 7
# ceil(7.2) = 8

# %%
#모듈 이름을 약자로 사용
import math as m
m.floor(7.2), m.ceil(7.2)
# Out:
# (7, 8)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#이런식으로 줄여씁니다 사실상의 표준(de facto standard)

# %%
# 모듈내의 함수를 직접 사용
from math import floor, ceil
floor(7.2), ceil(7.2)
# Out:
# (7, 8)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### 2. 내장모듈

# %%
import random
random.randint(1, 6)
# Out:
# 6

# %%
random.random()
# Out:
# 0.06314464197054159

# %%
random.choice([1, 3, 5, 7, 9])
# Out:
# 9

# %%
import datetime
datetime.datetime.today()
# Out:
# datetime.datetime(2021, 11, 24, 13, 56, 47, 323478)

# %%
datetime.datetime.today()
# Out:
# datetime.datetime(2021, 11, 24, 13, 57, 1, 395654)

# %%
from datetime import datetime
datetime.today()
# Out:
# datetime.datetime(2021, 11, 24, 13, 58, 37, 93670)

# %%
from datetime import date
date.today()
# Out:
# datetime.date(2021, 11, 24)

# %%
from datetime import timedelta
forty_days = timedelta(days=40)
date.today() + forty_days
# Out:
# datetime.date(2022, 1, 3)

# %%
date.today() + timedelta(days=100)
# Out:
# datetime.date(2022, 3, 4)
