# %% [markdown]
# # Unit 16. 반복문

# %% [markdown]
# ### 16-1 for, range

# %%
for i in range(5):
    print('안뇽', i)
# Out:
# 안뇽 0
# 안뇽 1
# 안뇽 2
# 안뇽 3
# 안뇽 4

# %%
for i in range(3,9):
    print('good', i)
# Out:
# good 3
# good 4
# good 5
# good 6
# good 7
# good 8

# %%
for i in range(1, 10, 2):
    print("hi", i)
# Out:
# hi 1
# hi 3
# hi 5
# hi 7
# hi 9

# %%
int (input())
for i in range(10, 1, -2):
    print('Hello, world', i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a836d2f0fa6c> in <module>
# ----> 1 int (input())
#       2 for i in range(10, 1, -2):
#       3     print('Hello, world', i)
#       4 print()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
for i in range():
    i *= 3
    print(i)
# Out:
# 0
# 3
# 6
# 9

# %%
#for loop의 index값은 변경시키지 말 것
for i in range(6):
    k = i * 2
    print(k)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### 16-3 squence 객체

# %%
a = [10, 20, 30, 40, 50]
for i in a:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
fruits = ('apple', 'pear', 'orange')
for fuits in fruits:
    print(fuits)
# Out:
# apple
# pear
# orange

# %%
for letter in 'Python':
    print(letter, end= ' ')
# Out:
# P y t h o n

# %% [markdown]
# - 반복문 응용

# %%
# 1에서 100까지 합
sum = 0
for i in range(1, 101):
    sum += i
print(sum)
# Out:
# 5050

# %%
# 1에서 10까지 곱

product = 1
for i in range(1, 11) :
    product *= i
print(product)
# Out:
# 3628800

# %%
import math
math.sqrt(4)
# Out:
# 2.0
