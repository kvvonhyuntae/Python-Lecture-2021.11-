# %% [markdown]
# # Unit 17. While 반복문

# %%
i = 0
while i < 5:
    print('Hello world', i)
    i += 1
# Out:
# Hello world 0
# Hello world 1
# Hello world 2
# Hello world 3
# Hello world 4

# %% [markdown]
# - 횟수가 정해지지 않은 반복문

# %%
import random as rd
rd.seed(2021)
dice = rd.randint(1, 6)
while dice != 3:
    print(dice, end = ' ')
    dice = rd.randint(1, 6)
# Out:
# 4 6 5
