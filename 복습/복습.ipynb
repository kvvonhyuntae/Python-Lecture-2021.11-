# %% [markdown]
# # Unit 16.6 심사문제 : 구구단 출력하기

# %%
a = int (input())
for i in range(1, 10):
    print(a,"*", i,"=", a * i)

# %% [markdown]
# # 17.6 심사문제: 교통카드 잔액 출력하기

# %%
balance = int(input())
fare = 1350

while balance - fare >=0:
    balance -= fare
    print(balance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-2b3d984a3c25> in <module>
# ----> 1 balance = int(input())
#       2 fare = 1350
#       3
#       4 while balance - fare >=0:
#       5     balance -= fare
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
#  # 18.6 심사문제: 두 수 사이의 숫자 중 3으로 끝나지 않는 숫자 출력하기

# %%
start, stop = map(int, input().split())
 
i = start
 
while True:
if i > stop:
    break
if i % 10==3:
    continue
    i +=1
    print(i, end=' ')
i += 1

# %%
a = int(input)
for i in range(a):
    for k in range(3-i):
            print(' ', end = '')
        for k in range(2*i+1):
            print('*', end = '')
        print()
    for i in range(2, -1, -1):
        for k in range(3-i):
            print(' ', end = '')
        for k in range(2*i+1):
            print('*', end = '')
        print()

# %% [markdown]
# # U.19 산모양으로 별 출력하기

# %%
n = int(input())
for i in range(n):
    for k in range(n-i-1):
        print(' ', end = '')
    for k in range(2*i+1):
        print('*', end = '')
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
text_list = text.split()
count_the = 0
for word in text_list:
   word = word.strip("',.").lower()
   if word == 'the':
       count_the += 1
print(count_the)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b21064089b82> in <module>
# ----> 1 text_list = text.split()
#       2 count_the = 0
#       3 for word in text_list:
#       4    word = word.strip("',.").lower()
#       5    if word == 'the':
#
# NameError: name 'text' is not defined

# %%
input_str = '51900;83000;158000;367500;250000;59200;128500;1304000'
price_list = list(map, int(input_str.split(';')))
price_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-145d892c1e22> in <module>
#       1 input_str = '51900;83000;158000;367500;250000;59200;128500;1304000'
# ----> 2 price_list = list(map, int(input_str.split(';')))
#       3 price_list
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
price_list.sort(reverse_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9e781cc56d38> in <module>
# ----> 1 price_list.sort(reverse_)
#
# NameError: name 'price_list' is not defined

# %%
price_list.sort(reverse=True)
price_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-942e89ec134b> in <module>
# ----> 1 price_list.sort(reverse=True)
#       2 price_list
#
# NameError: name 'price_list' is not defined

# %%
for price in price_list:
    print(f'{price:9,d}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-432557899021> in <module>
# ----> 1 for price in price_list:
#       2     print(f'{price:9,d}')
#
# NameError: name 'price_list' is not defined

# %%
#u25
#alpha bravo charlie delta
# 10 20 30 40
keys = input().split()
Values = list(map(int, input().split()))
x = dict(zip(keys, Values))
x
# Out:
# {}

# %%
del x['delta']
x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7b5eee7b9947> in <module>
# ----> 1 del x['delta']
#       2 x
#
# KeyError: 'delta'

# %%
for key, value in x.items():
    if value == 3.0:
        break
x.pop(key)
xs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d3ab0cb28baf> in <module>
#       2     if value == 3.0:
#       3         break
# ----> 4 x.pop(key)
#       5 x
#
# NameError: name 'key' is not defined
