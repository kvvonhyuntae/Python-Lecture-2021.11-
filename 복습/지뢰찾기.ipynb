# %%
a, b = map(int, input().split())
sq_list = [2 ** i for i in range(a, b+1)]
del sq_list[-1]
del sq_list[-2]
sq_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4f3349e58abe> in <module>
# ----> 1 a, b = map(int, input().split())
#       2 sq_list = [2 ** i for i in range(a, b+1)]
#       3 del sq_list[-1]
#       4 del sq_list[-2]
#       5 sq_list
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
import random
N = 8
mines = []
for _ in range(N):
        row = ''
        for _ in range(N):
            if random() > 0.7:
                row += '*'
            else:
                row += '.'
        mines.append(row)
for row in mines:
    for element in row:
        print((element, end=' '))

# %%
def print_mines(mat):
    for row in mat:
        for element in row:
            print(element, end='')
print()

# %%
print_mines(mines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-15b8d3eae11f> in <module>
# ----> 1 print_mines(mines)
#
# NameError: name 'mines' is not defined

# %%
pad_mines = []
pad_mines.append('.' * (N+2))
for i row in mines:
    line = '.'
    for element in row:
        line += element
        line += '.'
        pad_mines.append(line)
    pad_mines.append('.', (N+2))
    print_mines(pad_mines)
# Out:
#   File "<ipython-input-14-9b82986a1e0a>", line 3
#     for i row in mines:
#           ^
# SyntaxError: invalid syntax
