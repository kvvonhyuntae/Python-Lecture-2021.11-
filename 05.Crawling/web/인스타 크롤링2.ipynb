# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd 
from urllib.parse import quote
import unicodedata
import re
from tqdm.notebook import tqdm
import requests 
import sys
import json
import datetime

# %%
with open('kakaoapikey.txt') as file:
    kakao_key = file.read()

# %%
len(kakao_key)
# Out:
# 32

# %%
df = pd.read_csv('인스타place.csv')
df
# Out:
#                 place
# 0              디벨츠잇뮤직
# 1                 NaN
# 2                 NaN
# 3    갤러리아 Gourmet 494
# 4                 NaN
# ..                ...
# 359               NaN
# 360               NaN
# 361               NaN
# 362               NaN
# 363               NaN
#
# [364 rows x 1 columns]

# %%
df
# Out:
# [['디벨츠잇뮤직'],
#  [nan],
#  [nan],
#  ['갤러리아 Gourmet 494'],
#  [nan],
#  ['Clique Records'],
#  [nan],
#  ['합정역'],
#  [nan],
#  ['DÖNUT'],
#  [nan],
#  ['피터판'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['엘피와음악사랑'],
#  [nan],
#  [nan],
#  [nan],
#  ['덕소-팔당구간 한강산책로'],
#  [nan],
#  ['히피히피'],
#  [nan],
#  [nan],
#  [nan],
#  ['DOPE RECORDS/Entertainment'],
#  [nan],
#  [nan],
#  [nan],
#  ['Home Sweet Home'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['Seoul, Korea'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['꿈엔들'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['Busan 釜山, South Korea'],
#  ['Busan 釜山, South Korea'],
#  ['엘피와음악사랑'],
#  [nan],
#  ['덕소-팔당구간 한강산책로'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['만평 Vinyl music'],
#  ['DÖNUT'],
#  [nan],
#  ['순천블루노트'],
#  [nan],
#  [nan],
#  ['앤틱소리'],
#  ['만평 Vinyl music'],
#  ['덕소-팔당구간 한강산책로'],
#  ['플랫폼엘 Platform-L'],
#  [nan],
#  [nan],
#  [nan],
#  ['Seoul, Korea'],
# ...
